# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# line plot
data = np.random.rand(5)

# %%
data
# Out:
# array([0.6333635 , 0.96973239, 0.55605651, 0.39381076, 0.2250706 ])

# %%
data.shape
# Out:
# (5,)

# %%
plt.plot(data)

# %%
# Figures and Subplots
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

plt.plot(np.random.randn(50).cumsum(),'k--')
ax2.plot(np.random.randn(50).cumsum(),'k--')

# %% [markdown]
# Creating a figure with a grid of subplots is a very common task, so matplotlib
# includes a convenience method, plt.subplots , that creates a new figure and returns
# a NumPy array containing the created subplot objects:

# %%
fig, axes = plt.subplots(2,3)
axes[0,1].plot(np.random.rand(10))
plt.show()

# %%
fig, axes = plt.subplots(2,2,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins=50,color='k',alpha=0.5)

plt.subplots_adjust(wspace=0,hspace=0)
plt.figure(figsize=(10,8))

# %% [markdown]
# #### Colors, MArkers and Line Style

# %%
plt.plot(np.random.randn(30).cumsum(),'ko--',drawstyle='steps-post',label='steps')
plt.plot(np.random.randn(30).cumsum(),'ko--',label='ayo')
plt.legend(loc='best')
plt.xlim([1,20])
plt.ylim([-5,10])
# linear interpolation by default
# Out:
# (-5.0, 10.0)

# %% [markdown]
# #### Ticks, Labels and Legends

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum())
ax.set_xticks([0, 250, 500, 750, 1000])
ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],\
    rotation=30, fontsize='small')


props = {
    'title':"First",
    'xlabel':'Stages'
}
ax.set(**props)
plt.show()

# %%
# adding legends
